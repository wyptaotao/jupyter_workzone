# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

train=pd.read_csv("train.csv")
print(train.keys)
# Out:
# <bound method NDFrame.keys of             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            0    Male   27              1.0         46.0                   1
# 1            1  Female   44              1.0         28.0                   0
# 2            2    Male   52              1.0         46.0                   0
# 3            3    Male   23              1.0         46.0                   1
# 4            4  Female   43              1.0         28.0                   0
# ...        ...     ...  ...              ...          ...                 ...
# 304883  304883  Female   20              1.0          7.0                   0
# 304884  304884  Female   24              1.0         20.0                   0
# 304885  304885  Female   25              1.0         36.0                   1
# 304886  304886    Male   22              1.0          8.0                   1
# 304887  304887  Female   26              1.0         28.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0         < 1 Year             No         33138.0                 152.0
# 1        > 2 Years            Yes         60529.0                  26.0
# 2        > 2 Years            Yes         22476.0                 124.0
# 3         < 1 Year             No          2630.0                 152.0
# 4         1-2 Year            Yes         32543.0                 124.0
# ...            ...            ...             ...                   ...
# 304883    < 1 Year            Yes          2630.0                 160.0
# 304884    < 1 Year            Yes          2630.0                  26.0
# 304885    < 1 Year             No         26826.0                 152.0
# 304886    < 1 Year             No         71548.0                 152.0
# 304887    < 1 Year             No         31674.0                 152.0
#
#         Vintage  Response
# 0           223         0
# 1           158         1
# 2           226         1
# 3           163         0
# 4            56         1
# ...         ...       ...
# 304883      264         0
# 304884       63         0
# 304885       26         0
# 304886      140         0
# 304887       88         0
#
# [304888 rows x 12 columns]>

# %%
tu=train.corr()
plt.subplots(figsize=(12, 12)) # 设置画面大小
sb.heatmap(tu, annot=True, vmax=1, square=True, cmap="Reds")
plt.show()
